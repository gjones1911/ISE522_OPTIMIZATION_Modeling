# %%
import matplotlib.pyplot as plt
import networkx as nx

# %%
G =  nx.DiGraph()

G.add_node(0)
G.add_node(1)
G.add_node(2)
G.add_node(3)
G.add_node(4)
G.add_node(5)
G.add_node(6)
G.add_node(7)
G.add_node(8)
G.add_node(9)
G.add_node(10)

G.add_edge(0,1, Weight = 100)
G.add_edge(0,2, Weight = 120)
G.add_edge(0,3, Weight = 140)
G.add_edge(0,4, Weight = 160)
G.add_edge(0,5, Weight = 220)
G.add_edge(0,6, Weight = 280)
G.add_edge(0,7, Weight = 370)
G.add_edge(0,8, Weight = 490)
G.add_edge(0,9, Weight = 610)
G.add_edge(0,10, Weight = 780)

G.add_edge(1,2, Weight = 100)
G.add_edge(1,3, Weight = 120)
G.add_edge(1,4, Weight = 140)
G.add_edge(1,5, Weight = 180)
G.add_edge(1,6, Weight = 220)
G.add_edge(1,7, Weight = 310)
G.add_edge(1,8, Weight = 430)
G.add_edge(1,9, Weight = 550)
G.add_edge(1,10, Weight = 700)

G.add_edge(2,3, Weight = 100)
G.add_edge(2,4, Weight = 120)
G.add_edge(2,5, Weight = 140)
G.add_edge(2,6, Weight = 160)
G.add_edge(2,7, Weight = 250)
G.add_edge(2,8, Weight = 370)
G.add_edge(2,9, Weight = 490)
G.add_edge(2,10, Weight = 620)

G.add_edge(3,4, Weight = 100)
G.add_edge(3,5, Weight = 100)
G.add_edge(3,6, Weight = 100)
G.add_edge(3,7, Weight = 190)
G.add_edge(3,8, Weight = 310)
G.add_edge(3,9, Weight = 430)
G.add_edge(3,10, Weight = 540)

G.add_edge(4,5, Weight = 100)
G.add_edge(4,6, Weight = 100)
G.add_edge(4,7, Weight = 190)
G.add_edge(4,8, Weight = 310)
G.add_edge(4,9, Weight = 430)
G.add_edge(4,10, Weight = 540)

G.add_edge(5,6, Weight = 100)
G.add_edge(5,7, Weight = 190)
G.add_edge(5,8, Weight = 310)
G.add_edge(5,9, Weight = 430)
G.add_edge(5,10, Weight = 540)

G.add_edge(6,7, Weight = 100)
G.add_edge(6,8, Weight = 220)
G.add_edge(6,9, Weight = 340)
G.add_edge(6,10, Weight = 420)

G.add_edge(7,8, Weight = 100)
G.add_edge(7,9, Weight = 220)
G.add_edge(7,10, Weight = 260)

G.add_edge(8,9, Weight = 100)
G.add_edge(8,10, Weight = 100)

G.add_edge(9,10, Weight = 100)

# %%
edge_labels = nx.get_edge_attributes(G,"Weight")
pos = nx.kamada_kawai_layout(G)
plt.figure()
nx.draw_networkx(G, pos)
nx.draw_networkx_edge_labels(G, pos, edge_labels)
plt.axis('off')
plt.show()

# %%
print(nx.shortest_path(G, source=0, target=10, weight='Weight'))
# Out:
# [0, 3, 7, 8, 10]
